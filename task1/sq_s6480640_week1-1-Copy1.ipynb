# %% [markdown]
# Answers for Week 1
#
# * Name: Barbara Anna Chylinska
# * Username: bachylinska
# * Student s-number: S6480640
# * Group : AS5

# %% [markdown]
# x = 22/7

# %% [markdown]
# $$y=\frac{sin(x)}{x}$$

# %%
pi = 22/7 # Processed on Jupyter Hub

# %% [markdown]
# ![Me after I fail my math quiz.jpg](attachment:fb016d80-2a2e-4086-93e1-db25ca698793.jpg)

# %%
fact=6
fact*=5
fact*=4
fact*=3
fact*=2
print(fact)
# Out:
# 720

# %%
from scipy.constants import h
E=h*(2.42*10**28)
print(E)
# Out:
# 1.6035089762999996e-05

# %%
from scipy.constants import G, pi
a=149.6*10**9
P=365*24*60*60
m=4*pi**2*a**3/(G*P**2)
print(m)
# Out:
# 1.9912948922963452e+30

# %%
x1 = 10
x2 = 22/7
print(x1, end="")
print(x2, end="")
# Out:
# 103.142857142857143
