# %%
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

# %% [markdown]
# TERMINAL FUNCTIONS
# ls  mv  mkdir  cp  cd  rm  touch  rmdir  ln

# %% [markdown]
# GITHUB
# git status, git add, git commit, git push

# %% [markdown]
# CODE
# f strings

# %% [markdown]
# revise "useful linux info"

# %% [markdown]
# file permissisons in terminal

# %% [markdown]
# LISTS
# append(x), count(x), extend(x2), insert(i,x), index(x), remove(x), sort(), copy()
# TUPLES
# non changable
# SETS
# intersection, difference and union
