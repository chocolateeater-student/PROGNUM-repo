# %% [markdown]
# Answers for Week 1
#
# * Name: Barbara Anna Chylinska
# * Username: bachylinska
# * Student s-number: S6480640
# * Group : AS5

# %%
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

# %%
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

# %% [markdown]
# # Energy and frequency
#
# With Planck's constant $h$, we write the relation between energy and frequency as:
#
# $$E = hf$$

# %% [markdown]
# $$E = hc/\lambda$$

# %% [markdown]
# $$F = G\frac{m_1m_2}{R^2}$$

# %% [markdown]
# $$\displaystyle\sum_{k=0}^{\infty}\frac{1}{4k^2-1}=\frac{1}{2}$$

# %% [markdown]
# $$\displaystyle\int_{0}^{\pi}e^{ix}dx = 2i$$

# %%
from IPython.display import display, Math
from math import sin, pi

x = 9
Lambda = 0.5

s = rf"\sqrt({x}) = {x**0.5}\ and \sin(\lambda \pi)={sin(Lambda*pi)}"
print(s)
m = Math(s)
display(m)
# Out:
# \sqrt(9) = 3.0\ and \sin(\lambda \pi)=1.0
# $\displaystyle \sqrt(9) = 3.0\ and \sin(\lambda \pi)=1.0$

# %%
from math import factorial

a=factorial(100)
print(a)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %%
from math import * 
x=2
y=3
a= atan2(y,x)
b= tan(a)
c= y/x
print(f"hopefully, {b}={c}")
# Out:
# hopefully, 1.5=1.5

# %%
from math import atan2, degrees
x=float(input())
y=float(input())
a= atan2(y,x)
q=["1 quadrant", "2 quadrant", "3 quadrant", "4 quadrant"]
if 0<a<90:
    s= f"in the {q[0]}"
elif 90<a<180:
    s= f"in the {q[1]}"
elif 180<a<270:
    s= f"in the {q[2]}"
elif 270<a<360:
    s= f"in the {q[3]}"
elif a==0 or a== 90 or a==180 or a ==270 or a==360:
    s=rf"on an axis- guess which one ;)"

print(f"your angle is {a} and it lies {s}")
# Out:
#  2
#  4
# your angle is 1.1071487177940904 and it lies in the 1 quadrant

# %%
x= [1.36,  1.46,  1.41,  2.12,  0.42,  0.98,  0.45,  1.97, -0.24, 2.18]    #2.14
x.append(0.51)
x.remove(2.12)

a=slice(2,9,1)
print(x[a])
print(sum(x[a]))
# Out:
# [1.41, 0.42, 0.98, 0.45, 1.97, -0.24, 2.18]
# 7.17

# %%
night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]   #2.15
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]
n1=set(night1)
n2=set(night2)    
night=n1 & n2
print(night)
v= 5 in night
v2= 5 in n1
print (f"is 5 in the intersection set? {v}")
print (f"is 5 in the 1 set? {v2}")
# Out:
# {0, 1, 2, 3, 4}
# is 5 in the intersection set? False
# is 5 in the 1 set? True

# %%
a = b = [1,2,3,4]
c = b
a[2]=0
print(a)
print(b)
print(c)
# Out:
# [1, 2, 0, 4]
# [1, 2, 0, 4]
# [1, 2, 0, 4]

# %%
from numpy import random, std       #2.19
ran=random.normal(loc=0.0, scale=1.4, size=1000)
print(std(ran))
# Out:
# 1.3813863622134432

# %%
a=1
b=2
i=0
for i in range(0,49):
    a+=b
    b+=a
    i+=1
print(f"{a}=354224848179261915075")
# Out:
# 354224848179261915075=354224848179261915075

# %%
354224848179261915075
